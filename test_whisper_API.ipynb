# %%
from openai import OpenAI
from dotenv import load_dotenv

# %%
load_dotenv()
# Load the key to call the client.
client = OpenAI()

# %%
audio_file= open("/Users/edwardyang/code/ECEE6366-ASR-ClassProj/Data/violin_audios/audio_clips_part_1/dh_s02e16_clip_2054_2085.flac", "rb")
transcription = client.audio.transcriptions.create(
  model="whisper-1", 
  file=audio_file
)
print(transcription.text)
# Out:
# I'm not gonna hug you. I don't care if you are my grandfather. Ah, that's okay. Hugging's not really my thing. Mike, could you wait outside? I'd like to be alone with Zachary. Not a chance. Just curious. Why was it so important you see him? I don't know. I don't know. I don't know. I don't know. Just curious. Why was it so important you see me?
